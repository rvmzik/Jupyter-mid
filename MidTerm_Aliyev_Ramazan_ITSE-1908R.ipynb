# %% [markdown]
# <h1>Task 1</h1>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# <h1>#Inline my matplotlib</h1>

# %%
# %matplotlib inline

# %% [markdown]
# <h4>Take the first look at your data</h4>

# %%
#Read README file to understand the names of the columns
data = pd.read_csv("output 5.csv")
# Out:
# c:\users\ramik\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (5,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head(10)
# Out:
#   Date received                  Product  \
# 0    07/29/2013            Consumer Loan
# 1    07/29/2013  Bank account or service
# 2    07/29/2013  Bank account or service
# 3    07/29/2013  Bank account or service
# 4    07/29/2013                 Mortgage
# 5    07/29/2013  Bank account or service
# 6    07/29/2013          Debt collection
# 7    07/29/2013          Debt collection
# 8    07/29/2013              Credit card
# 9    07/29/2013                 Mortgage
#
#                              Sub-product  \
# 0                           Vehicle loan
# 1                       Checking account
# 2                       Checking account
# 3                       Checking account
# 4            Conventional fixed mortgage
# 5                       Checking account
# 6  Other (i.e. phone, health club, etc.)
# 7                          I do not know
# 8                                    NaN
# 9                         Other mortgage
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 670598 entries, 0 to 670597
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date received                 670598 non-null  object
#  1   Product                       670598 non-null  object
#  2   Sub-product                   472396 non-null  object
#  3   Issue                         670598 non-null  object
#  4   Sub-issue                     269868 non-null  object
#  5   Consumer complaint narrative  114704 non-null  object
#  6   Company public response       145197 non-null  object
#  7   Company                       670598 non-null  object
#  8   State                         665293 non-null  object
#  9   ZIP code                      665274 non-null  object
#  10  Tags                          94730 non-null   object
#  11  Consumer consent provided?    208151 non-null  object
# ...

# %%
data.describe()
# Out:
#        Complaint ID
# count  6.705980e+05
# mean   1.145473e+06
# std    6.468630e+05
# min    1.000000e+00
# 25%    5.930575e+05
# 50%    1.174558e+06
# 75%    1.718337e+06
# max    2.218987e+06

# %% [markdown]
# <h1>Task 2</h1>

# %% [markdown]
# <h4>Dropping unrelevant data</h4>
# <h4>I believe that State column is unrelevant because it does not affect anything</h4>

# %%
data.drop('State', axis=1, inplace = True)
data
# Out:
#        Date received                  Product  \
# 0         07/29/2013            Consumer Loan
# 1         07/29/2013  Bank account or service
# 2         07/29/2013  Bank account or service
# 3         07/29/2013  Bank account or service
# 4         07/29/2013                 Mortgage
# ...              ...                      ...
# 670593    11/16/2016         Credit reporting
# 670594    10/26/2016                 Mortgage
# 670595    11/17/2016         Credit reporting
# 670596    09/22/2016              Credit card
# 670597    08/13/2016            Consumer Loan
#
#                                    Sub-product  \
# 0                                 Vehicle loan
# 1                             Checking account
# 2                             Checking account
# 3                             Checking account
# 4                  Conventional fixed mortgage
# ...                                        ...
# 670593                                     NaN
# ...

# %% [markdown]
# <h4>I believe that Company column is unrelevant because it does not affect anything</h4>

# %%
data.drop(columns='Company', axis=1, inplace = True)
data
# Out:
#        Date received                  Product  \
# 0         07/29/2013            Consumer Loan
# 1         07/29/2013  Bank account or service
# 2         07/29/2013  Bank account or service
# 3         07/29/2013  Bank account or service
# 4         07/29/2013                 Mortgage
# ...              ...                      ...
# 670593    11/16/2016         Credit reporting
# 670594    10/26/2016                 Mortgage
# 670595    11/17/2016         Credit reporting
# 670596    09/22/2016              Credit card
# 670597    08/13/2016            Consumer Loan
#
#                                    Sub-product  \
# 0                                 Vehicle loan
# 1                             Checking account
# 2                             Checking account
# 3                             Checking account
# 4                  Conventional fixed mortgage
# ...                                        ...
# 670593                                     NaN
# ...

# %% [markdown]
# <h1>Task 3</h1>

# %% [markdown]
# <h1>Calculate and visualize how many NaN valueas are there in my dataset.</h1>

# %%
data.isnull().sum()
# Out:
# Date received                        0
# Product                              0
# Sub-product                     198202
# Sub-issue                       400730
# Consumer complaint narrative    555894
# Company public response         525401
# ZIP code                          5324
# Tags                            575868
# Consumer consent provided?      462447
# Submitted via                        0
# Date sent to company                 0
# Company response to consumer         0
# Timely response?                     0
# Consumer disputed?               41419
# Complaint ID                         0
# dtype: int64

# %%
Mynull = data.isnull().sum().sum()
Mynull
# Out:
# 2765285

# %% [markdown]
# <h1>I use dropna to drop all rows that have any NaN values</h1>

# %%
data.dropna()
# Out:
#        Date received          Product                            Sub-product  \
# 57945     03/24/2015      Payday loan                            Payday loan
# 58103     03/19/2015  Debt collection                                Medical
# 58160     03/24/2015  Debt collection  Other (i.e. phone, health club, etc.)
# 58240     03/19/2015  Debt collection                          I do not know
# 58253     03/19/2015  Debt collection                          I do not know
# ...              ...              ...                                    ...
# 668237    08/09/2016  Debt collection                            Credit card
# 668517    09/01/2016  Debt collection  Other (i.e. phone, health club, etc.)
# 669282    08/18/2016  Debt collection                            Credit card
# 670148    08/12/2016  Debt collection  Other (i.e. phone, health club, etc.)
# 670435    08/16/2016  Debt collection  Other (i.e. phone, health club, etc.)
#
# ...

# %% [markdown]
# <h1>Task 4</h1>

# %% [markdown]
# <h4>Detecting outliers</h4>

# %%
data.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h1>Then encoding the categorical data</h1>

# %%
data_1["Tags"] = data["Tags"].astype('category')
data_1.dtypes
# Out:
# Date received                     object
# Product                           object
# Sub-product                       object
# Issue                             object
# Sub-issue                         object
# Consumer complaint narrative      object
# Company                           object
# State                             object
# ZIP code                          object
# Tags                            category
# Consumer consent provided?        object
# Submitted via                     object
# Date sent to company              object
# Company response to consumer      object
# Timely response?                  object
# Consumer disputed?                object
# Complaint ID                       int64
# dtype: object

# %%
data_1["Tags1"] = data_1["Tags"].cat.codes
data_1.head()
# Out:
#   Date received                  Product                  Sub-product  \
# 0    07/29/2013            Consumer Loan                 Vehicle loan
# 1    07/29/2013  Bank account or service             Checking account
# 2    07/29/2013  Bank account or service             Checking account
# 3    07/29/2013  Bank account or service             Checking account
# 4    07/29/2013                 Mortgage  Conventional fixed mortgage
#
#                                       Issue Sub-issue  \
# 0                Managing the loan or lease       NaN
# 1                 Using a debit or ATM card       NaN
# 2   Account opening, closing, or management       NaN
# 3                  Deposits and withdrawals       NaN
# 4  Loan servicing, payments, escrow account       NaN
#
#   Consumer complaint narrative                     Company State ZIP code  \
# 0                          NaN       Wells Fargo & Company    VA    24540
# ...

# %%
data_1
# Out:
#        Date received                  Product  \
# 0         07/29/2013            Consumer Loan
# 1         07/29/2013  Bank account or service
# 2         07/29/2013  Bank account or service
# 3         07/29/2013  Bank account or service
# 4         07/29/2013                 Mortgage
# ...              ...                      ...
# 670593    11/16/2016         Credit reporting
# 670594    10/26/2016                 Mortgage
# 670595    11/17/2016         Credit reporting
# 670596    09/22/2016              Credit card
# 670597    08/13/2016            Consumer Loan
#
#                                    Sub-product  \
# 0                                 Vehicle loan
# 1                             Checking account
# 2                             Checking account
# 3                             Checking account
# 4                  Conventional fixed mortgage
# ...                                        ...
# 670593                                     NaN
# ...

# %% [markdown]
# <h4>next i want to drop outliers </h4>

# %%
data_1.drop(data_1[data_1['Complaint ID'] > 468000].index, axis=0, inplace = True)

# %%
data_1.boxplot('Complaint ID')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h1>Task 5 </h1>

# %%
import seaborn as sns

# %% [markdown]
# <h1>I used heatmap to visualize relations these data</h1>

# %%
ax = plt.figure(figsize=(20,20))
corrMatrix = data_1.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(data_1.Product, color='#F08080', ec='#414142')
# Out:
# (array([  631., 71625.,  4403.,     0., 19752.,  3650.,     0.,  9324.,
#         24312.,   166.]),
#  array([0. , 0.7, 1.4, 2.1, 2.8, 3.5, 4.2, 4.9, 5.6, 6.3, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data_1.Issue, color='#64fd00', ec='#414142')
# Out:
# (array([71286., 24356., 13100.,  6471.,  3631.,  3389.,  7239.,  2548.,
#          1399.,   444.]),
#  array([ 0.,  7., 14., 21., 28., 35., 42., 49., 56., 63., 70.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# <h1>I used histograms to visualize these data</h1>
